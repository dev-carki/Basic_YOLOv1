# %%
import ultralytics
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')  # load a pretrained YOLO11n detection model

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data=r'C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data.yaml', epochs=10, patience=5, imgsz=416)
# Out:
# New https://pypi.org/project/ultralytics/8.3.168 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.167  Python-3.12.7 torch-2.7.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# ...

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 73
# ...

# %%
# 테스트 이미지

from glob import glob

test_image_list = glob(r'C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\*')

print(len(test_image_list))

test_image_list.sort()

for i in range(len(test_image_list)):

    print('i = ',i, test_image_list[i])
# Out:
# 843
# i =  0 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1.png
# i =  1 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\10.png
# i =  2 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\100.png
# i =  3 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1003.png
# i =  4 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1004.png
# i =  5 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1005.png
# i =  6 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1006.png
# i =  7 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1007.png
# i =  8 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1009.png
# ...

# %%
results = model(source=r'C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images', save=True)
# Out:
# image 1/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1.png: 416x320 (no detections), 19.5ms
# image 2/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\10.png: 416x320 (no detections), 4.9ms
# image 3/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\100.png: 416x320 (no detections), 4.7ms
# image 4/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1003.png: 416x320 (no detections), 5.0ms
# image 5/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1004.png: 416x320 (no detections), 5.5ms
# image 6/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1005.png: 416x320 (no detections), 7.0ms
# image 7/843 C:\Users\USER\Desktop\dev\Deep_Learning\YOLOv1\data\ai03-level1-project\test_images\1006.png: 416x320 (no detections), 5.3ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 843
